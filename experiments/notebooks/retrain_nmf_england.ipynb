# %% [markdown]
# # NMF Retraining — England Training Corpus (3,943 articles)
#
# **Purpose:** Retrain NMF on the updated England training data from Supabase.
# **Data source:** `data/training/eng_training.csv` (synced via `sync_from_supabase.py`)
# **Previous model:** trained on ~3,972 articles from CSV. This retrains on 3,943 from Supabase.
# **Key question:** Do the 30 topics hold, or do names need updating?

# %%
import sys
sys.path.insert(0, "../..")

import logging
import pandas as pd
import numpy as np
from pathlib import Path

logging.basicConfig(level=logging.INFO)

from model_pipeline.training.s02_cleaning import run_cleaning
from model_pipeline.training.s03_spacy_processing import run_spacy_processing
from model_pipeline.training.s04_vectorisation import run_vectorisation, build_vectorizer
from model_pipeline.training.s05_nmf_training import run_nmf_training, get_top_words_per_topic
from model_pipeline.training.s06_topic_allocation import TOPIC_NAMES

import logging
logging.getLogger("gensim").setLevel(logging.WARNING)

from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %% [markdown]
# ## 1. Load England training data

# %%
preprocessed_path = Path("../../data/training/eng_training_preprocessed.parquet")

if preprocessed_path.exists():
    print("Loading preprocessed data (skipping cleaning + spaCy)...")
    df = pd.read_parquet(preprocessed_path)
    SKIP_PREPROCESSING = True
else:
    csv_path = Path("../../data/training/eng_training.csv")
    df = pd.read_csv(csv_path)
    SKIP_PREPROCESSING = False

print(f"Loaded: {df.shape}")
print(f"Skip preprocessing: {SKIP_PREPROCESSING}")
# Out:
# Loaded: (3943, 13)
# Skip preprocessing: False

# %% [markdown]
# ## 2. Prepare text column
#
# The Supabase schema has `title` and `text` as separate columns. The pipeline expects a combined `text` column. Also rename `article_date` → `date` to match pipeline expectations.

# %%
if not SKIP_PREPROCESSING:
    # Combine title + text (same as s01_data_loader)
    df["text"] = df["title"].fillna("") + "\n\n" + df["text"].fillna("")
    df["date"] = pd.to_datetime(df["article_date"], errors="coerce")
    print(f"Text combined. Sample length: {df['text'].str.len().describe()}")
else:
    print("Skipped — using preprocessed data")
# Out:
# Text combined. Sample length: count     3943.000000
# mean      4247.591681
# std       2843.243155
# min        148.000000
# 25%       2551.000000
# 50%       3877.000000
# 75%       5095.000000
# max      32328.000000
# Name: text, dtype: float64

# %% [markdown]
# ## 3. Cleaning (s02)

# %%
if not SKIP_PREPROCESSING:
    df = run_cleaning(df)
    print(f"After cleaning: {df.shape}")
    print(f"Empty text_clean: {(df['text_clean'].str.len() == 0).sum()}")
else:
    print("Skipped — using preprocessed data")
# Out:
# INFO:model_pipeline.training.s02_cleaning:Step 02 (cleaning): starting. Input shape=(3943, 14)
# INFO:model_pipeline.training.s02_cleaning:Step 02 (cleaning): complete. Output shape=(3943, 15)
# INFO:model_pipeline.training.s02_cleaning:Empty cleaned texts: 0
# After cleaning: (3943, 15)
# Empty text_clean: 0

# %% [markdown]
# ## 4. spaCy processing (s03)
#
# This takes a few minutes on ~4k articles.

# %%
if not SKIP_PREPROCESSING:
    df = run_spacy_processing(df)
    print(f"After spaCy: {df.shape}")
    print(f"Empty text_final: {(df['text_final'].str.len() == 0).sum()}")
    print(f"Avg tokens per doc: {df['tokens_final'].apply(len).mean():.0f}")
else:
    print("Skipped — using preprocessed data")
# Out:
# INFO:model_pipeline.training.s03_spacy_processing:Step 03 (spacy): starting. Input shape=(3943, 15)
# INFO:model_pipeline.training.s03_spacy_processing:Loading spaCy model: en_core_web_sm
# INFO:model_pipeline.training.s03_spacy_processing:spaCy processing complete (tokens_after_spacy created).
# INFO:model_pipeline.training.s03_spacy_processing:Post-spaCy junk filtering complete (tokens_final + text_final created).
# INFO:model_pipeline.training.s03_spacy_processing:Empty text_final rows: 0
# INFO:model_pipeline.training.s03_spacy_processing:Step 03 (spacy): complete. Output shape=(3943, 18)
# After spaCy: (3943, 18)
# Empty text_final: 0
# Avg tokens per doc: 217

# %%
if not SKIP_PREPROCESSING:
    df.to_parquet("../../data/training/eng_training_preprocessed.parquet")
    print(f"Saved preprocessed data: {df.shape}")
else:
    print("Already loaded from parquet")
# Out:
# Saved preprocessed data: (3943, 18)

# %% [markdown]
# ## 5. TF-IDF vectorisation (s04)

# %%
# Using same params as config.yaml: min_df=3, max_df=0.85, max_features=3000, ngram_range=(1,2)
vec_out = run_vectorisation(df)
print(f"TF-IDF matrix: {vec_out.X.shape}")
print(f"Vocabulary size: {len(vec_out.feature_names)}")
print(f"Sample features: {vec_out.feature_names[:20].tolist()}")
# Out:
# INFO:model_pipeline.training.s04_vectorisation:Step 04 (vectorisation): starting. Input shape=(3943, 18)
# INFO:model_pipeline.training.s04_vectorisation:TF-IDF shape: (3943, 3000)
# INFO:model_pipeline.training.s04_vectorisation:Vectorizer params: min_df=3 max_df=0.85 max_features=3000 ngram_range=(1, 2)
# INFO:model_pipeline.training.s04_vectorisation:Sample features: ['ab', 'ability', 'able', 'absence', 'absence absence', 'absence pupil', 'absence school', 'absent', 'absent pupil', 'absentee', 'absolute', 'abuse', 'academic', 'academies', 'academisation', 'academy', 'academy academy', 'academy financial', 'academy freedom', 'academy funding']
# TF-IDF matrix: (3943, 3000)
# Vocabulary size: 3000
# Sample features: ['ab', 'ability', 'able', 'absence', 'absence absence', 'absence pupil', 'absence school', 'absent', 'absent pupil', 'absentee', 'absolute', 'abuse', 'academic', 'academies', 'academisation', 'academy', 'academy academy', 'academy financial', 'academy freedom', 'academy funding']

# %% [markdown]
# ## 6. Train NMF (k=30)

# %%
nmf_out = run_nmf_training(vec_out.X, n_topics=30, random_state=42, init="nndsvd", max_iter=1000)
print(f"W shape: {nmf_out.W.shape}")
print(f"H shape: {nmf_out.H.shape}")
print(f"Reconstruction error: {nmf_out.reconstruction_error:.6f}")
# Out:
# INFO:model_pipeline.training.s05_nmf_training:Step 05 (NMF): starting. X shape=(3943, 3000)
# INFO:model_pipeline.training.s05_nmf_training:Step 05 (NMF): complete.
# INFO:model_pipeline.training.s05_nmf_training:W shape=(3943, 30) | H shape=(30, 3000)
# INFO:model_pipeline.training.s05_nmf_training:Reconstruction error: 53.164861
# W shape: (3943, 30)
# H shape: (30, 3000)
# Reconstruction error: 53.164861

# %%
## 7. Coherence sweep (gensim c_v)
# Compare with previous run
from model_pipeline.training.s07_evaluation import evaluate_coherence_over_topic_range

texts_tokens = df["tokens_final"].tolist()

df_coh = evaluate_coherence_over_topic_range(
    X=vec_out.X,
    feature_names=vec_out.feature_names,
    texts_tokens=texts_tokens,
    topic_range=range(5, 55, 5),
    n_top_words=10,
    random_state=42,
    init="nndsvd",
    max_iter=1000,
)

print(df_coh.to_string(index=False))

# Compare with previous
import matplotlib.pyplot as plt

prev = pd.read_csv("../../data/evaluation_outputs/coherence_sweep.csv")

plt.figure(figsize=(10, 4))
plt.plot(prev["n_topics"], prev["coherence_cv"], marker="o", label="Previous (3,972 articles)")
plt.plot(df_coh["n_topics"], df_coh["coherence_cv"], marker="s", label="Current (3,943 articles)")
plt.axvline(x=30, color="red", linestyle="--", alpha=0.5, label="k=30")
plt.xlabel("Number of topics (k)")
plt.ylabel("Coherence (c_v)")
plt.title("Coherence comparison: old vs new England corpus")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# INFO:model_pipeline.training.s07_evaluation:Coherence sweep: topic_range=[5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=5
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=10
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=15
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=20
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=25
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=30
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=35
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=40
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=45
# INFO:model_pipeline.training.s07_evaluation:Testing coherence for n_topics=50
#  n_topics  coherence_cv
#         5      0.599247
#        10      0.659455
#        15      0.675446
#        20      0.677915
#        25      0.688071
#        30      0.690240
#        35      0.693619
#        40      0.691831
#        45      0.685906
#        50      0.688328

# %% [markdown]
# #### k=35 was tested as it showed marginally higher coherence (0.694 vs 0.690 at k=30). However, the additional 5 topics were too fragmented — two fell outside scope (pension/legal contracts, post-16 qualifications), one was vague rhetoric (skills/opportunity), and only two were substantively meaningful splits (GCSE subjects, tutoring/NTP). The coherence difference is negligible (0.004) and does not justify the loss of topic interpretability. k=30 retained.

# %% [markdown]
# ## 8. Topic stability across random seeds

# %%
seeds = [42, 123, 456, 789, 1024]
H_matrices = []

for seed in seeds:
    model = NMF(n_components=30, init="nndsvda", random_state=seed, max_iter=1000)
    model.fit(vec_out.X)
    H_matrices.append(model.components_)
    print(f"Seed {seed}: recon error = {model.reconstruction_err_:.4f}")

# Compare all pairs of H matrices
pair_scores = []
for i in range(len(seeds)):
    for j in range(i + 1, len(seeds)):
        sim = cosine_similarity(H_matrices[i], H_matrices[j])
        # Best match for each topic in run i against run j
        best_matches = sim.max(axis=1).mean()
        pair_scores.append(best_matches)
        print(f"Seeds {seeds[i]} vs {seeds[j]}: avg best-match similarity = {best_matches:.4f}")

avg_stability = np.mean(pair_scores)
print(f"\nOverall topic stability: {avg_stability:.4f}")
print(f"Previous stability (old model): 0.94")
print(f"Interpretation: >0.90 = highly stable, 0.80-0.90 = acceptable, <0.80 = unstable")
# Out:
# Seed 42: recon error = 53.1649
# Seed 123: recon error = 53.1550
# Seed 456: recon error = 53.1972
# Seed 789: recon error = 53.2163
# Seed 1024: recon error = 53.1973
# Seeds 42 vs 123: avg best-match similarity = 0.9314
# Seeds 42 vs 456: avg best-match similarity = 0.9557
# Seeds 42 vs 789: avg best-match similarity = 0.9557
# Seeds 42 vs 1024: avg best-match similarity = 0.9786
# Seeds 123 vs 456: avg best-match similarity = 0.8897
# Seeds 123 vs 789: avg best-match similarity = 0.9285
# Seeds 123 vs 1024: avg best-match similarity = 0.9473
# Seeds 456 vs 789: avg best-match similarity = 0.9029
# Seeds 456 vs 1024: avg best-match similarity = 0.9400
# Seeds 789 vs 1024: avg best-match similarity = 0.9455
#
# Overall topic stability: 0.9375
# Previous stability (old model): 0.94
# Interpretation: >0.90 = highly stable, 0.80-0.90 = acceptable, <0.80 = unstable

# %% [markdown]
# ## 9. Save evaluation results

# %%
# Save new coherence results
coherence_df = pd.DataFrame({
    "n_topics": [5, 10, 15, 20, 25, 30, 35, 40, 45, 50],
    "coherence_cv": [0.599247, 0.659455, 0.675446, 0.677915, 0.688071, 0.690240, 0.693619, 0.691831, 0.685906, 0.688328]
})
coherence_df.to_csv("../../data/evaluation_outputs/coherence_sweep_v2.csv", index=False)

# Save stability results
stability_df = pd.DataFrame({
    "metric": ["avg_stability", "previous_stability"],
    "value": [avg_stability, 0.94]
})
stability_df.to_csv("../../data/evaluation_outputs/stability_seeds_v2.csv", index=False)

print("Saved to data/evaluation_outputs/")
# Out:
# Saved to data/evaluation_outputs/

# %% [markdown]
# ## 10. Inspect topics — top words per topic
#
# Compare with previous topic names to see if they still hold.

# %%
topics = get_top_words_per_topic(nmf_out.nmf_model, vec_out.feature_names, n_top_words=100)

# Display stopwords — these don't affect the model, just make the top words easier to read
display_stop = {
    "school", "education", "pupil", "student", "teacher", "year", "new", "work",
    "time", "say", "make", "good", "need", "use", "know", "want", "come", "take",
    "people", "government", "report", "system", "support", "include", "provide",
    "number", "change", "part", "set", "high", "low", "level", "national", "local",
    "public", "service", "also", "would", "could", "one", "two", "first", "last",
    "week", "month", "day", "told", "said", "according", "cent", "per", "per cent",
    "child", "children", "young", "staff", "area", "programme", "policy",
    "guidance", "framework", "response", "statement", "proposal", "approach",
    "review", "update", "document", "detail", "section", "datum", "figure",
    "survey", "rate", "score", "point", "proportion", "percentage",
    "organisation", "department", "committee", "institute", "foundation",
    "summit", "voice", "stakeholder", "partnership", "engagement",
    "scheme", "initiative", "pilot", "introduce", "implement", "launch",
    "office", "official", "notification", "recipient", "correspondence",
    "cookie", "banner", "subscribe", "contact", "submit", "accessibility",
    "share", "print", "visit", "site", "experience", "article", "news", "blog",
    "interesting", "fact", "previous", "current", "date", "information",
    "different", "large", "place", "individual", "view", "analysis",
    "thing", "way", "job"
}

print(f"{'Topic':>5}  {'Previous Name':<35}  Top 30 Words (display stopwords removed)")
print("=" * 140)
for i, words in enumerate(topics):
    filtered = [w for w in words if w not in display_stop and len(w) > 2][:30]
    prev_name = TOPIC_NAMES.get(i, "???")
    print(f"{i:>5}  {prev_name:<35}  {', '.join(filtered)}")
# Out:
# Topic  Previous Name                        Top 30 Words (display stopwords removed)
# ============================================================================================================================================
#     0  child_and_family_support             family, child school, care, life, early, parent, attendance, school child, poverty, standard, country, social, child education, child child, opportunity, young people, social care, vulnerable, child social, child young, sure, classroom, child poverty, great, chance, right, parent child, education child, child care, nursery
#     1  academy_finance_and_oversight        academy, authority education, late information, education skill, school academy, late, local authority, authority, skill, information action, provider england, assurance, skill vocational, vocational training, management assurance, academy funding, academy financial, assurance school, esfa, training school, financial management, england education, education provider, management, esfa late, agency academy, vocational, action education, skill agency, college local
#     2  mat_governance                       trust, academy, academy trust, mat, trust school, ceo, school trust, chain, trust academy, executive, chief executive, financial, multi academy, governance, merger, multi, chief, finance, improvement, notice, reserve, large trust, delta, management, education trust, school improvement, academy academy, trust ceo, account, decision
#     3  teacher_pay                          pay, rise, strb, pay rise, award, support staff, offer, pay award, body, recommendation, salary, teacher body, increase, teacher pay, inflation, condition, deal, school teacher, union, wage, budget, employer, rise teacher, pay offer, pension, leader, remit, pay condition, keegan, teacher leader
#     4  ofsted_inspections                   inspection, inspector, ofsted, death, watchdog, school inspection, spielman, leader, chief inspector, headteacher, perry, training, complaint, judgment, coroner, inspectorate, concern, inadequate, oliver, process, caversham, chief, provider, outstanding, inquest, inspection school, lead inspector, inspector school, school leader, evidence
#     5  academic_attainment                  grade, entry, subject, gcse, result, pandemic, math, english, pre pandemic, gap, pre, increase, science, english math, pass, language, german, french, fall, qualification, east, old, girl, standard, grade grade, attainment, popular, boy, entry grade, spanish
#     6  pupil_absence                        absence, attendance, persistent, persistent absence, absent, session, pandemic, illness, unauthorised, absence pupil, unauthorised absence, pupil absence, school attendance, pre pandemic, fine, pre, overall absence, school absence, pupil absent, tracker, absence school, pupil session, attendance tracker, hub, secondary, absence absence, severe, severe absence, disadvantaged pupil, covid
#     7  dfe_intervention                     notice, warning notice, warning, academy, dfe regional, regional director, regional, director, notice academy, reason issue, notice warning, urn notice, urn, council warning, trust reason, trust relation, judgement dfe, west, relation, east, inspection school, judgement, dfe, reason, inspection, school academy, inadequate ofsted, north, local authority, north west
#     8  send_provision                       council, deficit, valve, safety valve, authority, safety, local authority, agreement, override, bailout, admission, statutory, plan, budget, council school, send, legal, school council, financial, cost, case, spokesperson, council deficit, decision, deal, local government, duty, transport, county, school deficit
#     9  teacher_strikes                      union, strike, member, ballot, action, neu, strike action, industrial, nasuwt, industrial action, secretary, general secretary, dispute, talk, general, naht, turnout, education union, offer, leader, pay, national education, threshold, union member, motion, conference, vote, deal, turnout threshold, negotiation
#    10  apprenticeships                      apprenticeship, skill, employer, apprentice, career, qualification, opportunity, young people, training, college, learner, technical, provider, course, degree, industry, business, university, route, growth, future, construction, economy, levy, sector, placement, degree apprenticeship, quality, world, employment
#    11  exam_regulation                      ofqual, exam, qualification, regulator, chief regulator, board, exam board, assessment, gcse, result, college, school college, ofqual chief, chief, screen, paper, pearson, arrangement, technical, aqa, regulator ofqual, bauckham, technical qualification, student result, sir, ocr, regulation, btec, breach, vocational technical
#    12  raac_crisis                          raac, building, dfe, concrete, raac school, school building, school raac, estate, responsible body, rebuilding, capital, risk, responsible, temporary, list, condition, questionnaire, body, project, school rebuilding, material, safety, mitigation, minister, repair, school estate, rebuild, collapse, setting, barran
#    13  examinations_and_assessment          disadvantaged, disadvantaged pupil, group, attainment, school pupil, gap, pupil school, likely, disadvantage, pupil pupil, average, difference, datalab, age, cohort, state, progress, peer, census, roll, class, secondary school, epi, pupil likely, session, group pupil, disadvantage gap, language, gender, premium
#    14  school_funding                       meal, free school, free, school meal, food, eligible, universal, pupil premium, premium, poverty, eligibility, cost, fsm, family, eligible free, london, universal credit, income, auto enrolment, auto, credit, pupil eligible, infant, enrolment, household, child poverty, school food, mayor, funding, child eligible
#    15  education_politics                   labour, minister, party, phillipson, secretary, conservative, education secretary, election, reform, shadow, bill, private, private school, starmer, shadow education, labour government, school minister, bridget, general, state, parliament, bridget phillipson, plan, mckinnell, standard, academy, vat, conference, sir, education minister
#    16  education_research                   nuffield, research, nuffield foundation, justice, project, social, evidence, grant, researcher, society, justice system, ada, economic, life, inequality, challenge, professor, university, racial, development, future, study, family, welfare, event, impact, fund, application, strategy, outcome
#    17  leadership_appointments              role, executive, chief, director, chair, board, ceo, chief executive, leadership, senior, appointment, community, leader, head, interim, deputy, member, officer, adviser, headteacher, sir, university, keen, team, group, trustee, charity, school community, principal, fed
#    18  ai_and_edtech                        technology, tool, digital, lesson, tech, edtech, generative, artificial, artificial intelligence, world, ai tool, intelligence, innovation, future, human, workload, chatgpt, potential, classroom, product, resource, learner, bett, educator, opportunity, expert, risk, learning, evidence, planning
#    19  post_16_education                    health, mental, mental health, young people, nhs, health service, health support, wellbeing, care, leader, child young, child mental, waiting, social, intervention, access, college, issue, treatment, help, youth, team, health issue, support service, health social, education support, condition, social care, wait, service school
#    20  mental_health                        curriculum, subject, oak, art, knowledge, music, assessment, francis, young people, language, science, curriculum assessment, national curriculum, ebacc, lesson, resource, gcse, quality, sport, key, stage, design, recommendation, climate, breadth, opportunity, evidence, creative, quango, national academy
#    21  safeguarding                         parent, behaviour, complaint, case, abuse, legal, phone, sex, incident, childcare, school parent, uniform, parent school, court, family, social medium, police, leader, investigation, medium, rshe, issue, parent child, right, online, law, misconduct, concern, mobile, head
#    22  teacher_recruitment                  recruitment, teaching, retention, trainee, target, training, subject, career, workload, teacher training, profession, bursary, teacher recruitment, workforce, hour, recruitment retention, leader, school teacher, provider, itt, secondary, supply, early career, shortage, professional, dfe, physics, classroom, working, math
#    23  accountability_reform                funding, budget, cost, spending, cash, tutoring, school funding, school budget, dfe, allocation, financial, cut, money, grant, funding school, increase, capital, rise, saving, real, deficit, pupil funding, formula, treasury, pressure, fund, additional, leader, investment, school cost
#    24  curriculum_policy                    suspension, exclusion, exclusion suspension, permanent exclusion, behaviour, permanent, suspension pupil, suspension exclusion, pupil suspension, increase, statistic, spell, alternative provision, sen, disruptive, attendance, ogat, provision, pandemic, alternative, academic, risk, secondary, reason, isolation, pre, pupil pupil, pre pandemic, internal, boy
#    25  attendance_hubs                      card, report card, judgment, improvement, grade, inspection, inclusion, leader, standard, accountability, parent, evaluation, single, headline, reform, evaluation area, ofsted, headline grade, sub, plan, concern, school improvement, school report, intervention, strong, clear, sub judgment, inspectorate, exemplary, judgement
#    26  disadvantage_and_attainment_gaps     send, special, mainstream, special school, ehcp, provision, mainstream school, plan, reform, inclusion, specialist, inclusive, send system, educational, special educational, educational need, education health, health care, sen, setting, care, care plan, alternative provision, disability, alternative, need disability, health, child special, child young, intervention
#    27  free_school_meals                    test, key stage, stage, math, key, attainment, progress, result, sat, reading, assessment, standard, measure, paper, phonic, table, performance, english, check, writing, pupil standard, mark, sta, raw, average, progress measure, dfe, testing, literacy, capita
#    28  school_places                        primary, secondary, primary school, secondary school, london, primary secondary, roll, mat, primary pupil, closure, headteacher, north, capacity, nursery, school primary, east, school secondary, drop, spare, school place, region, population, head, borough, school capacity, lambeth, west, small, likely, school pupil
#    29  exclusions                           club, breakfast, breakfast club, free breakfast, free, adopter, early adopter, food, childcare, school breakfast, early, club school, family, start, primary school, activity, poverty, hour, primary, provision, parent, wraparound, healthy, cost, school early, uniform, minute, school food, child poverty, trial

# %% [markdown]
# #### Topic naming sensitivity to keyword depth: Topic names vary depending on whether the top 20, 30, or 50 keywords are reviewed. At 20 keywords, names reflect the topic's core (e.g. "teacher_pay"); at 50, peripheral keywords pull names toward broader framings (e.g. "teacher_workforce_conditions"). Top 30 keywords were used as the default for both human and LLM review, balancing specificity with scope. This is itself a specification choice — the number of keywords shown to the reviewer shapes how the topic is understood and labelled.

# %% [markdown]
# #### In my review, I found that while many of the topics still make sense, several have clearly shifted and need relabelling. For example, child_and_family_support now feels more focused on vulnerability, and send_provision seems to be more about local funding rather than SEND specifically. I also noticed that school_funding is really about free school meals and poverty, while post_16_education now reflects mental health, and mental_health has instead shifted towards curriculum-related content. Similarly, curriculum_policy is actually about exclusions and suspensions, attendance_hubs looks more like report cards or accountability, and disadvantage_and_attainment_gaps has effectively become the SEND topic. In addition, free_school_meals appears to focus on assessment (like maths and key stages), exclusions now seems to be about breakfast clubs, and school_places is unclear and may need further review.

# %% [markdown]
# #### Contestability implications of topic relabelling: 13/30 topics required relabelling after retraining on a <1% different corpus. The content did not change — the indices shuffled. This means topic labels are a specification choice, not a model output. A mislabelled topic (e.g. "send_provision" applied to council deficit keywords) would cause stakeholders to misinterpret cross-jurisdiction findings. Two researchers on near-identical data would produce identical coherence scores but different labels. Topic naming should be logged and audited as a specification decision alongside model parameters.

# %% [markdown]
# ## 11. LLM-suggested topic names
#
# Send top words per topic to Claude for naming suggestions. Compare with existing names.

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from anthropic import Anthropic
import json
import re

load_dotenv(Path("../../.env"))
client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"])

# Build keyword lists (without display stopwords)
topic_keyword_lines = []
for i, words in enumerate(topics):
    filtered = [w for w in words if w not in display_stop and len(w) > 2][:30]
    topic_keyword_lines.append(f"Topic {i}: {', '.join(filtered)}")

old_name_lines = []
for i in range(30):
    old_name_lines.append(f"Topic {i}: previous name was '{TOPIC_NAMES.get(i, 'unknown')}'")

prompt = f"""You are helping label topics from an NMF topic model trained on UK education policy documents (2023-2025).
The corpus includes articles from government departments, think tanks, media outlets, and research organisations in England.

STEP 1: For each topic below, suggest a name based ONLY on the keywords. Do not look ahead to Step 2.

{chr(10).join(topic_keyword_lines)}

For each topic return:
- suggested_name (2-4 words, snake_case)
- explanation (one sentence)

STEP 2: Now compare your suggestions against these previous names that were assigned to the SAME topic indices (but the model was retrained on slightly different data, so topics may have shuffled or recomposed):

{chr(10).join(old_name_lines)}

For each topic, assess:
- old_name_assessment: "MATCHES" (old name still fits the keywords), "SHIFTED" (same broad area but emphasis changed), or "WRONG" (old name does not describe these keywords)
- old_name_note: one sentence explaining why

Return ONLY a JSON list combining both steps:
[
  {{"topic": 0, "suggested_name": "name", "explanation": "why", "old_name_assessment": "MATCHES", "old_name_note": "why"}},
  ...
]
No other text, no markdown, no code fences."""

response = client.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=4096,
    messages=[{"role": "user", "content": prompt}],
)

llm_text = response.content[0].text

# Strip markdown code fences if present
cleaned = re.sub(r'^```(?:json)?\n?', '', llm_text.strip())
cleaned = re.sub(r'\n?```$', '', cleaned.strip())
llm_results = json.loads(cleaned)

# Summary table
print(f"{'Topic':>5}  {'Old Name':<30}  {'Status':<8}  {'LLM Suggestion':<30}  Notes")
print("=" * 140)
for r in llm_results:
    i = r["topic"]
    old = TOPIC_NAMES.get(i, "???")
    print(f"{i:>5}  {old:<30}  {r['old_name_assessment']:<8}  {r['suggested_name']:<30}  {r['old_name_note']}")

# Detailed explanations
print("\n\nDETAILED EXPLANATIONS:")
print("=" * 80)
for r in llm_results:
    print(f"\nTopic {r['topic']}: {r['suggested_name']}")
    print(f"  Why: {r['explanation']}")
    print(f"  Old name '{TOPIC_NAMES.get(r['topic'], '???')}': {r['old_name_assessment']} — {r['old_name_note']}")

# Save so you don't have to re-run the API call
with open("../../data/evaluation_outputs/llm_topic_review.json", "w") as f:
    json.dump(llm_results, f, indent=2)
print("\nSaved to data/evaluation_outputs/llm_topic_review.json")
# Out:
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# Topic  Old Name                        Status    LLM Suggestion                  Notes
# ============================================================================================================================================
#     0  child_and_family_support        MATCHES   child_family_support            Keywords clearly focus on family, child care, poverty, and social support systems.
#     1  academy_finance_and_oversight   MATCHES   academy_oversight               Keywords include academy funding, financial management, ESFA, and authority oversight.
#     2  mat_governance                  MATCHES   academy_trust_governance        Keywords heavily feature academy trusts, MATs, CEOs, and governance structures.
#     3  teacher_pay                     MATCHES   teacher_pay                     Keywords directly relate to pay rises, STRB, teacher pay awards, and salary negotiations.
#     4  ofsted_inspections              MATCHES   ofsted_inspections              Keywords focus on Ofsted, inspections, inspectors, and inspection-related deaths and concerns.
#     5  academic_attainment             SHIFTED   exam_results                    Previous 'academic_attainment' is broader while these keywords specifically focus on exam grades and results.
#     6  pupil_absence                   MATCHES   pupil_absence                   Keywords directly relate to absence, persistent absence, attendance tracking, and pandemic impacts.
#     7  dfe_intervention                MATCHES   dfe_intervention                Keywords include warning notices, DfE regional directors, and intervention processes.
#     8  send_provision                  WRONG     council_finances                Keywords focus on council deficits and safety valve agreements rather than SEND provision specifically.
#     9  teacher_strikes                 MATCHES   teacher_strikes                 Keywords clearly focus on unions, strikes, industrial action, and NEU activities.
#    10  apprenticeships                 MATCHES   apprenticeships_skills          Keywords focus on apprenticeships, skills, vocational training, and employer engagement.
#    11  exam_regulation                 MATCHES   exam_regulation                 Keywords include Ofqual, exam boards, qualification regulation, and assessment oversight.
#    12  raac_crisis                     MATCHES   raac_crisis                     Keywords specifically focus on RAAC, school buildings, rebuilding programs, and safety concerns.
#    13  examinations_and_assessment     WRONG     disadvantage_gaps               Previous name suggested exams but keywords clearly focus on disadvantaged pupils and attainment gaps.
#    14  school_funding                  SHIFTED   free_school_meals               Previous 'school_funding' was broader while these keywords specifically focus on free meals and poverty-related funding.
#    15  education_politics              MATCHES   education_politics              Keywords include Labour, Conservative parties, education ministers, and political reforms.
#    16  education_research              MATCHES   education_research              Keywords focus on Nuffield Foundation, research projects, and educational evidence gathering.
#    17  leadership_appointments         MATCHES   leadership_appointments         Keywords focus on CEO roles, executive appointments, leadership positions, and board memberships.
#    18  ai_and_edtech                   MATCHES   ai_edtech                       Keywords include AI, artificial intelligence, edtech, digital tools, and classroom technology.
#    19  post_16_education               SHIFTED   mental_health                   Previous 'post_16_education' doesn't match as keywords focus on mental health, NHS, and wellbeing services.
#    20  mental_health                   SHIFTED   curriculum_policy               Previous 'mental_health' doesn't match as keywords focus on curriculum, subjects, and Oak National Academy.
#    21  safeguarding                    MATCHES   safeguarding_behaviour          Keywords include abuse, complaints, investigations, and child protection concerns.
#    22  teacher_recruitment             MATCHES   teacher_recruitment             Keywords focus on recruitment, retention, teacher training, and workforce issues.
#    23  accountability_reform           SHIFTED   school_funding                  Previous 'accountability_reform' doesn't match as keywords clearly focus on funding, budgets, and financial matters.
#    24  curriculum_policy               SHIFTED   exclusions_suspension           Previous 'curriculum_policy' doesn't match as keywords focus on exclusions, suspensions, and behaviour issues.
#    25  attendance_hubs                 SHIFTED   inspection_accountability       Previous 'attendance_hubs' doesn't match as keywords focus on inspection grades, report cards, and accountability.
#    26  disadvantage_and_attainment_gaps  SHIFTED   send_provision                  Previous 'disadvantage_and_attainment_gaps' is less specific than these keywords which clearly focus on SEND and special needs.
#    27  free_school_meals               SHIFTED   standardized_testing            Previous 'free_school_meals' doesn't match as keywords focus on testing, SATs, and assessment measures.
#    28  school_places                   MATCHES   school_places                   Keywords focus on school capacity, pupil rolls, primary/secondary provision, and regional differences.
#    29  exclusions                      WRONG     breakfast_clubs                 Previous 'exclusions' doesn't match as keywords clearly focus on breakfast clubs and early adopter programs.
#
#
# DETAILED EXPLANATIONS:
# ================================================================================
#
# Topic 0: child_family_support
#   Why: Covers early childhood, family welfare, poverty, and social care for vulnerable children.
#   Old name 'child_and_family_support': MATCHES — Keywords clearly focus on family, child care, poverty, and social support systems.
#
# Topic 1: academy_oversight
#   Why: Deals with academy funding, financial management, and education authority oversight.
#   Old name 'academy_finance_and_oversight': MATCHES — Keywords include academy funding, financial management, ESFA, and authority oversight.
#
# Topic 2: academy_trust_governance
#   Why: Focuses on multi-academy trusts, governance structures, and executive leadership.
#   Old name 'mat_governance': MATCHES — Keywords heavily feature academy trusts, MATs, CEOs, and governance structures.
#
# Topic 3: teacher_pay
#   Why: Addresses teacher pay awards, salary increases, and remuneration conditions.
#   Old name 'teacher_pay': MATCHES — Keywords directly relate to pay rises, STRB, teacher pay awards, and salary negotiations.
#
# Topic 4: ofsted_inspections
#   Why: Concerns school inspections, Ofsted processes, and inspector judgments.
#   Old name 'ofsted_inspections': MATCHES — Keywords focus on Ofsted, inspections, inspectors, and inspection-related deaths and concerns.
#
# Topic 5: exam_results
#   Why: Covers GCSE grades, subject performance, and pandemic impact on qualifications.
#   Old name 'academic_attainment': SHIFTED — Previous 'academic_attainment' is broader while these keywords specifically focus on exam grades and results.
#
# Topic 6: pupil_absence
#   Why: Addresses persistent absence, attendance issues, and post-pandemic attendance patterns.
#   Old name 'pupil_absence': MATCHES — Keywords directly relate to absence, persistent absence, attendance tracking, and pandemic impacts.
#
# Topic 7: dfe_intervention
#   Why: Covers DfE warning notices, regional director interventions, and academy oversight.
#   Old name 'dfe_intervention': MATCHES — Keywords include warning notices, DfE regional directors, and intervention processes.
#
# Topic 8: council_finances
#   Why: Deals with local authority deficits, safety valve agreements, and council budget issues.
#   Old name 'send_provision': WRONG — Keywords focus on council deficits and safety valve agreements rather than SEND provision specifically.
#
# Topic 9: teacher_strikes
#   Why: Covers union industrial action, strike ballots, and education sector disputes.
#   Old name 'teacher_strikes': MATCHES — Keywords clearly focus on unions, strikes, industrial action, and NEU activities.
#
# Topic 10: apprenticeships_skills
#   Why: Addresses apprenticeship programs, vocational training, and skills development.
#   Old name 'apprenticeships': MATCHES — Keywords focus on apprenticeships, skills, vocational training, and employer engagement.
#
# Topic 11: exam_regulation
#   Why: Concerns Ofqual oversight, exam boards, and qualification regulation.
#   Old name 'exam_regulation': MATCHES — Keywords include Ofqual, exam boards, qualification regulation, and assessment oversight.
#
# Topic 12: raac_crisis
#   Why: Addresses RAAC concrete issues in school buildings and rebuilding programs.
#   Old name 'raac_crisis': MATCHES — Keywords specifically focus on RAAC, school buildings, rebuilding programs, and safety concerns.
#
# Topic 13: disadvantage_gaps
#   Why: Focuses on disadvantaged pupils, attainment gaps, and educational inequality.
#   Old name 'examinations_and_assessment': WRONG — Previous name suggested exams but keywords clearly focus on disadvantaged pupils and attainment gaps.
#
# Topic 14: free_school_meals
#   Why: Covers free school meal eligibility, pupil premium, and poverty indicators.
#   Old name 'school_funding': SHIFTED — Previous 'school_funding' was broader while these keywords specifically focus on free meals and poverty-related funding.
#
# Topic 15: education_politics
#   Why: Addresses political parties, ministers, elections, and education policy debates.
#   Old name 'education_politics': MATCHES — Keywords include Labour, Conservative parties, education ministers, and political reforms.
#
# Topic 16: education_research
#   Why: Covers Nuffield Foundation research, social justice studies, and educational evidence.
#   Old name 'education_research': MATCHES — Keywords focus on Nuffield Foundation, research projects, and educational evidence gathering.
#
# Topic 17: leadership_appointments
#   Why: Addresses executive appointments, leadership roles, and governance positions.
#   Old name 'leadership_appointments': MATCHES — Keywords focus on CEO roles, executive appointments, leadership positions, and board memberships.
#
# Topic 18: ai_edtech
#   Why: Covers artificial intelligence, digital tools, and educational technology innovations.
#   Old name 'ai_and_edtech': MATCHES — Keywords include AI, artificial intelligence, edtech, digital tools, and classroom technology.
#
# Topic 19: mental_health
#   Why: Addresses mental health support, NHS services, and wellbeing interventions for young people.
#   Old name 'post_16_education': SHIFTED — Previous 'post_16_education' doesn't match as keywords focus on mental health, NHS, and wellbeing services.
#
# Topic 20: curriculum_policy
#   Why: Covers national curriculum, subject knowledge, Oak resources, and curriculum assessment.
#   Old name 'mental_health': SHIFTED — Previous 'mental_health' doesn't match as keywords focus on curriculum, subjects, and Oak National Academy.
#
# Topic 21: safeguarding_behaviour
#   Why: Addresses parent complaints, behaviour issues, abuse cases, and child protection.
#   Old name 'safeguarding': MATCHES — Keywords include abuse, complaints, investigations, and child protection concerns.
#
# Topic 22: teacher_recruitment
#   Why: Covers teacher recruitment, retention, training, and workforce challenges.
#   Old name 'teacher_recruitment': MATCHES — Keywords focus on recruitment, retention, teacher training, and workforce issues.
#
# Topic 23: school_funding
#   Why: Addresses school budgets, funding allocations, financial pressures, and cost increases.
#   Old name 'accountability_reform': SHIFTED — Previous 'accountability_reform' doesn't match as keywords clearly focus on funding, budgets, and financial matters.
#
# Topic 24: exclusions_suspension
#   Why: Covers school exclusions, suspensions, behaviour management, and alternative provision.
#   Old name 'curriculum_policy': SHIFTED — Previous 'curriculum_policy' doesn't match as keywords focus on exclusions, suspensions, and behaviour issues.
#
# Topic 25: inspection_accountability
#   Why: Addresses inspection report cards, judgment grades, and school accountability measures.
#   Old name 'attendance_hubs': SHIFTED — Previous 'attendance_hubs' doesn't match as keywords focus on inspection grades, report cards, and accountability.
#
# Topic 26: send_provision
#   Why: Covers special educational needs, EHCP plans, mainstream inclusion, and SEND reform.
#   Old name 'disadvantage_and_attainment_gaps': SHIFTED — Previous 'disadvantage_and_attainment_gaps' is less specific than these keywords which clearly focus on SEND and special needs.
#
# Topic 27: standardized_testing
#   Why: Addresses key stage tests, SATs, assessment measures, and pupil performance data.
#   Old name 'free_school_meals': SHIFTED — Previous 'free_school_meals' doesn't match as keywords focus on testing, SATs, and assessment measures.
#
# Topic 28: school_places
#   Why: Covers primary and secondary school capacity, pupil rolls, and regional school provision.
#   Old name 'school_places': MATCHES — Keywords focus on school capacity, pupil rolls, primary/secondary provision, and regional differences.
#
# Topic 29: breakfast_clubs
#   Why: Addresses breakfast club provision, wraparound care, and early childhood support programs.
#   Old name 'exclusions': WRONG — Previous 'exclusions' doesn't match as keywords clearly focus on breakfast clubs and early adopter programs.
#
# Saved to data/evaluation_outputs/llm_topic_review.json

# %% [markdown]
# #### Topic labels were finalised using a combined LLM and manual review — the LLM identified potential drift, human judgment determined the final names. 11/30 topics were renamed; 19 retained their original labels.

# %% [markdown]
# # 12. Rename Topics

# %%
# Final topic name mapping (confirmed after manual + LLM review)
NEW_TOPIC_NAMES = {
    0: "child_and_family_support",
    1: "academy_finance_and_oversight",
    2: "mat_governance",
    3: "teacher_pay",
    4: "ofsted_inspections",
    5: "exam_results",
    6: "pupil_absence",
    7: "dfe_intervention",
    8: "local_authority_deficits",
    9: "teacher_strikes",
    10: "apprenticeships",
    11: "exam_regulation",
    12: "raac_crisis",
    13: "disadvantaged_groups",
    14: "free_school_meals",
    15: "education_politics",
    16: "education_research",
    17: "leadership_appointments",
    18: "ai_and_edtech",
    19: "mental_health",
    20: "curriculum",
    21: "safeguarding",
    22: "teacher_recruitment",
    23: "school_funding",
    24: "exclusions_suspensions",
    25: "report_cards",
    26: "send_inclusion",
    27: "primary_assessment",
    28: "school_places",
    29: "breakfast_clubs",
}

# Show changes from old names
changes = {k: (TOPIC_NAMES[k], v) for k, v in NEW_TOPIC_NAMES.items() if v != TOPIC_NAMES.get(k)}
print(f"Total changes: {len(changes)}/30")
print(f"\nCHANGED TOPICS:")
for k, (old, new) in sorted(changes.items()):
    print(f"  Topic {k}: '{old}' -> '{new}'")

unchanged = {k: v for k, v in NEW_TOPIC_NAMES.items() if v == TOPIC_NAMES.get(k)}
print(f"\nUNCHANGED: {len(unchanged)}/30")
# Out:
# Total changes: 12/30
#
# CHANGED TOPICS:
#   Topic 5: 'academic_attainment' -> 'exam_results'
#   Topic 8: 'send_provision' -> 'local_authority_deficits'
#   Topic 13: 'examinations_and_assessment' -> 'disadvantaged_groups'
#   Topic 14: 'school_funding' -> 'free_school_meals'
#   Topic 19: 'post_16_education' -> 'mental_health'
#   Topic 20: 'mental_health' -> 'curriculum'
#   Topic 23: 'accountability_reform' -> 'school_funding'
#   Topic 24: 'curriculum_policy' -> 'exclusions_suspensions'
#   Topic 25: 'attendance_hubs' -> 'report_cards'
#   Topic 26: 'disadvantage_and_attainment_gaps' -> 'send_inclusion'
#   Topic 27: 'free_school_meals' -> 'primary_assessment'
#   Topic 29: 'exclusions' -> 'breakfast_clubs'
#
# UNCHANGED: 18/30

# %% [markdown]
# ## 13. Topic distribution — how many articles per dominant topic?

# %%
dominant_topics = nmf_out.W.argmax(axis=1)
dominant_weights = nmf_out.W.max(axis=1)

topic_counts = pd.Series(dominant_topics).value_counts().sort_index()
topic_df = pd.DataFrame({
    "topic_num": topic_counts.index,
    "topic_name": [NEW_TOPIC_NAMES.get(i, "???") for i in topic_counts.index],
    "count": topic_counts.values,
    "pct": (topic_counts.values / len(dominant_topics) * 100).round(1),
})
print(topic_df.to_string(index=False))
print(f"\nDominant weight — min: {dominant_weights.min():.4f}, mean: {dominant_weights.mean():.4f}, max: {dominant_weights.max():.4f}")
# Out:
#  topic_num                    topic_name  count  pct
#          0      child_and_family_support     56  1.4
#          1 academy_finance_and_oversight    150  3.8
#          2                mat_governance    272  6.9
#          3                   teacher_pay    111  2.8
#          4            ofsted_inspections    238  6.0
#          5                  exam_results     97  2.5
#          6                 pupil_absence     90  2.3
#          7              dfe_intervention     82  2.1
#          8      local_authority_deficits     88  2.2
#          9               teacher_strikes    131  3.3
#         10               apprenticeships    144  3.7
#         11               exam_regulation    169  4.3
#         12                   raac_crisis    117  3.0
#         13          disadvantaged_groups    117  3.0
#         14             free_school_meals     76  1.9
#         15            education_politics    162  4.1
#         16            education_research    143  3.6
#         17       leadership_appointments    123  3.1
#         18                 ai_and_edtech    122  3.1
#         19                 mental_health     95  2.4
#         20                    curriculum    138  3.5
#         21                  safeguarding    201  5.1
#         22           teacher_recruitment    253  6.4
#         23                school_funding    174  4.4
#         24        exclusions_suspensions     51  1.3
#         25                  report_cards    117  3.0
#         26                send_inclusion    149  3.8
#         27            primary_assessment    115  2.9
#         28                 school_places    115  2.9
#         29               breakfast_clubs     47  1.2
#
# Dominant weight — min: 0.0129, mean: 0.1302, max: 0.3630

# %% [markdown]
# #### Topic distribution: 30 topics are well-distributed across 3,943 articles (range: 1.2%–6.9%). No single topic dominates. Largest topics reflect ed journalism coverage priorities (MAT governance 6.9%, teacher recruitment 6.4%, Ofsted 6.0%). Smallest topics (breakfast clubs 1.2%, exclusions 1.3%) are coherent policy domains with sufficient articles. Mean dominant weight is 0.13 — NMF spreads weight across topics, meaning most articles touch multiple policy areas. This distribution defines the baseline that Scotland and Ireland will be measured against.

# %% [markdown]
# ## 14. Topic distribution by source
#
# Check if any source dominates a topic (specification choice: corpus composition).

# %%
df["dominant_topic"] = dominant_topics
df["dominant_topic_name"] = df["dominant_topic"].map(NEW_TOPIC_NAMES)
ct = pd.crosstab(df["source"], df["dominant_topic_name"], normalize="columns").round(2)
print("Source distribution per topic (column-normalised):")
ct
# Out:
# Source distribution per topic (column-normalised):
# dominant_topic_name  academy_finance_and_oversight  ai_and_edtech  \
# source
# epi                                           0.00           0.03
# fed                                           0.01           0.20
# fft                                           0.00           0.01
# gov                                           0.99           0.18
# nuffield                                      0.00           0.00
# schoolsweek                                   0.00           0.57
#
# dominant_topic_name  apprenticeships  breakfast_clubs  \
# source
# epi                             0.01             0.00
# fed                             0.08             0.09
# fft                             0.01             0.00
# gov                             0.54             0.28
# nuffield                        0.01             0.00
# schoolsweek                     0.34             0.64
#
# dominant_topic_name  child_and_family_support  curriculum  dfe_intervention  \
# source
# epi                                      0.07        0.01              0.00
# fed                                      0.05        0.06              0.00
# fft                                      0.02        0.04              0.00
# gov                                      0.45        0.16              0.96
# nuffield                                 0.02        0.00              0.00
# schoolsweek                              0.39        0.73              0.04
#
# dominant_topic_name  disadvantaged_groups  education_politics  \
# source
# epi                                  0.09                0.01
# fed                                  0.00                0.01
# fft                                  0.40                0.00
# gov                                  0.00                0.01
# nuffield                             0.00                0.00
# schoolsweek                          0.51                0.98
#
# dominant_topic_name  education_research  ...  pupil_absence  raac_crisis  \
# source                                   ...
# epi                                0.13  ...           0.06         0.02
# fed                                0.06  ...           0.00         0.00
# fft                                0.02  ...           0.38         0.00
# gov                                0.03  ...           0.09         0.09
# nuffield                           0.66  ...           0.00         0.00
# schoolsweek                        0.10  ...           0.48         0.89
#
# dominant_topic_name  report_cards  safeguarding  school_funding  \
# source
# epi                          0.08          0.00            0.01
# fed                          0.07          0.01            0.00
# fft                          0.02          0.00            0.00
# gov                          0.13          0.13            0.08
# nuffield                     0.01          0.00            0.01
# schoolsweek                  0.70          0.86            0.90
#
# dominant_topic_name  school_places  send_inclusion  teacher_pay  \
# source
# epi                           0.04            0.00         0.00
# fed                           0.02            0.03         0.00
# fft                           0.04            0.00         0.00
# gov                           0.03            0.07         0.03
# nuffield                      0.01            0.01         0.00
# schoolsweek                   0.85            0.89         0.97
#
# dominant_topic_name  teacher_recruitment  teacher_strikes
# source
# epi                                 0.02             0.00
# fed                                 0.01             0.00
# fft                                 0.01             0.00
# gov                                 0.07             0.04
# nuffield                            0.01             0.00
# schoolsweek                         0.88             0.96
#
# [6 rows x 30 columns]

# %% [markdown]
# #### Markdown cell: Source concentration analysis reveals that several topics are almost entirely driven by a single source: academy oversight (99% GOV.UK), education politics (98% SchoolsWeek), teacher pay (97% SchoolsWeek). This is a proxy concentration finding — the topic structure partly reflects editorial and publication patterns, not just the underlying policy landscape. For cross-jurisdiction inference, this means absence of certain topics in Scotland/Ireland may reflect corpus composition differences rather than genuine policy divergence.

# %% [markdown]
# #### Source concentration as a contestability dimension: 7 of 30 topics are >90% driven by a single source (SchoolsWeek or GOV.UK). This means the topic structure partly reflects editorial patterns, not just the policy landscape. For cross-jurisdiction inference, when Scotland/Ireland documents don't cluster into these topics, it is ambiguous whether the policy area is absent in that jurisdiction or whether the topic only exists because of England's source composition. This ambiguity cannot be resolved by the model — it must be surfaced to stakeholders as a specification property. Proxy concentration (the proportion of topic variance explained by a single source) is one of the three computable dimensions in the specification scoring layer.

# %% [markdown]
# ## 15. k=25 and k=35 exploration
#
# Check what happens with fewer/more topics.

# %%
nmf_35 = NMF(n_components=35, init="nndsvd", random_state=42, max_iter=1000)
W_35 = nmf_35.fit_transform(vec_out.X)

topics_35 = get_top_words_per_topic(nmf_35, vec_out.feature_names, n_top_words=15)
for i, words in enumerate(topics_35):
    print(f"Topic {i:>2}: {', '.join(words)}")
# Out:
# Topic  0: child, family, care, child school, early, life, poverty, school child, social, child education, child child, standard, social care, attendance, service
# Topic  1: academy, authority education, late information, education skill, school academy, late, local authority, authority, skill, local, information action, provider england, assurance, information, skill vocational
# Topic  2: trust, academy, academy trust, mat, trust school, school trust, ceo, chain, trust academy, executive, chief executive, multi academy, governance, merger, improvement
# Topic  3: pay, rise, strb, pay rise, award, teacher, support staff, offer, pay award, body, government, staff, recommendation, salary, teacher body
# Topic  4: inspection, inspector, ofsted, report, judgment, watchdog, leader, death, school inspection, inspectorate, spielman, chief inspector, report card, card, concern
# Topic  5: grade, result, pandemic, entry, pre pandemic, gap, pre, gcse, standard, east, english, pass, increase, subject, grade grade
# Topic  6: absence, attendance, persistent, persistent absence, absent, session, illness, pandemic, unauthorised, pupil, absence pupil, unauthorised absence, pupil absence, school attendance, fine
# Topic  7: notice, warning notice, warning, academy, dfe regional, regional director, regional, director, notice academy, reason issue, notice warning, urn notice, urn, council warning, trust reason
# Topic  8: council, deficit, valve, safety valve, local, authority, safety, local authority, agreement, override, service, bailout, admission, statutory, council school
# Topic  9: union, strike, member, ballot, action, neu, strike action, industrial, nasuwt, industrial action, secretary, general secretary, talk, dispute, general
# Topic 10: apprenticeship, apprentice, employer, degree, skill, training, provider, route, levy, degree apprenticeship, career, business, course, training provider, technical
# Topic 11: ofqual, regulator, chief regulator, qualification, chief, ofqual chief, organisation, interim, bauckham, sir, assessment, school college, result, regulator ofqual, exam
# Topic 12: raac, building, concrete, raac school, dfe, school building, school raac, estate, responsible body, rebuilding, department, capital, responsible, government, list
# Topic 13: pupil, disadvantaged, disadvantaged pupil, school pupil, group, pupil school, gap, attainment, likely, report, pupil pupil, average, disadvantage, age, difference
# Topic 14: meal, free school, free, school meal, food, eligible, universal, pupil premium, premium, eligibility, poverty, cost, fsm, family, eligible free
# Topic 15: labour, minister, government, party, phillipson, secretary, conservative, education secretary, reform, policy, election, shadow, mp, bill, committee
# Topic 16: foundation, nuffield, research, nuffield foundation, justice, report, project, policy, social, uk, evidence, institute, researcher, grant, society
# Topic 17: role, director, executive, chief, ceo, chair, board, chief executive, job, leadership, senior, leader, appointment, community, head
# Topic 18: ai, technology, tool, digital, use, teacher, lesson, edtech, tech, generative, ai tool, artificial intelligence, artificial, student, intelligence
# Topic 19: health, mental, mental health, support, service, nhs, health service, staff, health support, young, young people, people, wellbeing, leader, child mental
# Topic 20: primary, secondary, primary school, secondary school, london, place, primary secondary, roll, mat, primary pupil, headteacher, closure, pupil, capacity, school primary
# Topic 21: pension, contract, legal, case, court, investigation, company, dfe, staff, information, tps, public, firm, department, bromcom
# Topic 22: teacher, recruitment, teaching, retention, trainee, target, training, career, workload, profession, teacher training, workforce, teacher recruitment, bursary, leader
# Topic 23: funding, budget, cost, spending, school funding, school budget, government, cash, cut, financial, allocation, money, grant, dfe, increase
# Topic 24: curriculum, oak, subject, assessment, knowledge, lesson, resource, francis, art, national curriculum, music, quality, national academy, curriculum assessment, national
# Topic 25: parent, behaviour, report, card, report card, childcare, school parent, staff, parent school, attendance, abuse, leader, complaint, family, uniform
# Topic 26: send, special, need, mainstream, ehcp, special school, system, provision, mainstream school, plan, reform, support, inclusion, specialist, child
# Topic 27: test, key stage, stage, key, progress, attainment, result, assessment, sat, reading, measure, standard, phonic, paper, performance
# Topic 28: club, breakfast, breakfast club, free breakfast, free, adopter, early adopter, food, childcare, school breakfast, early, club school, family, government, start
# Topic 29: math, subject, language, gcse, entry, english, science, ebacc, english math, hub, qualification, art, physics, german, mathematic
# Topic 30: suspension, exclusion, exclusion suspension, permanent exclusion, behaviour, permanent, pupil, suspension pupil, suspension exclusion, pupil suspension, statistic, increase, spell, ap, alternative provision
# Topic 31: student, qualification, college, technical, course, university, result, btec, placement, sixth, sixth form, technical qualification, form, provider, general qualification
# Topic 32: skill, people, young, young people, opportunity, learner, career, life, future, world, college, work, digital, uk, system
# Topic 33: tutoring, ntp, subsidy, national tutoring, tutor, dfe, tuition, cash, catch, gap, academic, target, course, national, nfer
# Topic 34: exam, board, exam board, gcse, paper, aqa, student, ocr, screen, digital, pearson, cyber, ofqual, assessment, arrangement

# %%
nmf_25 = NMF(n_components=25, init="nndsvd", random_state=42, max_iter=1000)
W_25 = nmf_25.fit_transform(vec_out.X)

topics_25 = get_top_words_per_topic(nmf_25, vec_out.feature_names, n_top_words=15)
for i, words in enumerate(topics_25):
    print(f"Topic {i:>2}: {', '.join(words)}")
# Out:
# Topic  0: child, family, care, child school, life, early, young, support, need, parent, standard, school child, attendance, poverty, country
# Topic  1: academy, authority education, late information, education skill, school academy, late, local authority, authority, skill, local, information action, provider england, assurance, information, skill vocational
# Topic  2: trust, academy, academy trust, mat, trust school, ceo, school trust, chain, executive, trust academy, chief executive, financial, improvement, multi academy, staff
# Topic  3: pay, rise, strb, pay rise, teacher, award, support staff, offer, pay award, staff, body, government, recommendation, salary, teacher body
# Topic  4: inspection, inspector, ofsted, report, judgment, watchdog, leader, death, school inspection, report card, card, inspectorate, chief inspector, spielman, grade
# Topic  5: grade, entry, gcse, subject, student, result, pandemic, math, english, pre pandemic, gap, pre, increase, science, english math
# Topic  6: absence, attendance, persistent, persistent absence, absent, session, pupil, illness, pandemic, unauthorised, absence pupil, unauthorised absence, pupil absence, pre pandemic, school attendance
# Topic  7: notice, warning notice, warning, academy, dfe regional, regional director, regional, director, notice academy, reason issue, notice warning, urn notice, urn, council warning, trust reason
# Topic  8: council, send, deficit, special, need, ehcp, mainstream, special school, local, plan, provision, valve, system, safety valve, authority
# Topic  9: union, strike, member, ballot, action, neu, strike action, industrial, nasuwt, industrial action, secretary, general secretary, dispute, talk, general
# Topic 10: apprenticeship, skill, employer, people, career, student, apprentice, young, qualification, young people, opportunity, training, college, learner, technical
# Topic 11: ofqual, exam, qualification, student, regulator, chief regulator, board, exam board, assessment, gcse, result, college, organisation, school college, ofqual chief
# Topic 12: raac, building, dfe, concrete, school building, raac school, school raac, estate, department, responsible body, capital, rebuilding, government, risk, responsible
# Topic 13: pupil, disadvantaged, primary, secondary, attainment, disadvantaged pupil, school pupil, gap, secondary school, group, pupil school, primary school, likely, average, progress
# Topic 14: free, meal, club, breakfast, free school, breakfast club, school meal, food, free breakfast, poverty, cost, family, universal, eligible, adopter
# Topic 15: labour, minister, government, party, phillipson, secretary, reform, conservative, education secretary, policy, election, shadow, mp, bill, committee
# Topic 16: foundation, nuffield, research, nuffield foundation, justice, report, project, policy, uk, social, evidence, system, institute, researcher, grant
# Topic 17: role, executive, chief, director, chair, board, ceo, chief executive, job, leadership, senior, appointment, community, head, leader
# Topic 18: ai, technology, tool, student, digital, teacher, lesson, use, oak, edtech, tech, generative, resource, artificial intelligence, artificial
# Topic 19: health, mental, mental health, support, service, young, young people, people, nhs, health service, health support, staff, wellbeing, child young, leader
# Topic 20: curriculum, key stage, test, stage, math, key, assessment, subject, reading, progress, english, sat, measure, knowledge, language
# Topic 21: parent, staff, behaviour, report, complaint, case, abuse, legal, card, leader, information, school parent, childcare, report card, parent school
# Topic 22: teacher, recruitment, teaching, retention, target, trainee, training, subject, career, secondary, workload, teacher training, profession, bursary, workforce
# Topic 23: funding, budget, cost, spending, cash, government, school funding, tutoring, school budget, financial, dfe, cut, allocation, money, grant
# Topic 24: suspension, exclusion, exclusion suspension, permanent exclusion, behaviour, pupil, permanent, suspension pupil, suspension exclusion, pupil suspension, ap, increase, statistic, alternative provision, spell

# %% [markdown]
# #### The choice of k — the number of topics — is a human decision that the model presents as structure. A stakeholder looking at the dashboard sees 30 topics and assumes those are the policy domains that exist. They are not — they are the domains a researcher chose to make visible. At k=25 there are 25; at k=35 there are 35. The policy landscape did not change — the lens did. A contestable system must make this dependency explicit. The Build Your Model dashboard page operationalises this by letting stakeholders change k themselves and observe how findings shift: SEND and council finance appear as one issue at k=25 but separate at k=30; tutoring emerges from school funding only at k=35. This turns k from an invisible technical decision into a visible interpretive choice, making the stakeholder a participant in the specification rather than a consumer of it. The broader governance implication is that sensitivity disclosure should be a minimum standard for any AI system used in public policy. Before an AI-derived finding informs a policy decision, the producing system should demonstrate what the finding looks like under at least two alternative parameter configurations and report whether it held. If it did not — as with the SEND/council finance merge at k=25 — that should be disclosed alongside the finding, not buried in a technical appendix. This is analogous to how clinical trials report sensitivity analyses: the primary result is accompanied by checks showing what happens when assumptions change. AI systems in public policy should meet the same bar. Currently, none do.

# %% [markdown]
# ## 16. Export topic comparison CSV — new topics with top 100 words + old topic mapping

# %%
import joblib
import json

# Load old model for comparison
old_nmf = joblib.load("../../experiments/outputs/runs/2026-02-27_215011/nmf_model.joblib")
old_vec = joblib.load("../../experiments/outputs/runs/2026-02-27_215011/vectorizer.joblib")
old_names = json.load(open("../../experiments/outputs/runs/2026-02-27_215011/topic_names.json"))
old_features = old_vec.get_feature_names_out()

# Align vocabularies for cosine matching
old_vocab = {w: i for i, w in enumerate(old_features)}
new_vocab = {w: i for i, w in enumerate(vec_out.feature_names)}
shared = sorted(set(old_features) & set(vec_out.feature_names))

old_H = np.zeros((30, len(shared)))
new_H = np.zeros((30, len(shared)))
for j, word in enumerate(shared):
    old_H[:, j] = old_nmf.components_[:, old_vocab[word]]
    new_H[:, j] = nmf_out.H[:, new_vocab[word]]

sim = cosine_similarity(new_H, old_H)

rows = []
for new_i in range(30):
    old_i = sim[new_i].argmax()
    similarity = sim[new_i, old_i]
    old_name = old_names.get(str(old_i), old_names.get(old_i, "???"))
    new_name = NEW_TOPIC_NAMES.get(new_i, "???")
    renamed = "Yes" if new_name != old_name else "No"
    
    # Top 100 words excluding display stopwords
    all_idx = nmf_out.H[new_i].argsort()[::-1]
    top_words = []
    for idx in all_idx:
        word = vec_out.feature_names[idx]
        if word not in display_stop and len(word) > 2:
            top_words.append(word)
        if len(top_words) >= 100:
            break
    
    rows.append({
        "new_topic_num": new_i,
        "new_topic_name": new_name,
        "old_topic_num": old_i,
        "old_topic_name": old_name,
        "renamed": renamed,
        "cosine_similarity": round(similarity, 4),
        "match_quality": "strong" if similarity > 0.8 else "moderate" if similarity > 0.5 else "weak",
        "top_100_words": ", ".join(top_words),
    })

topic_csv = pd.DataFrame(rows)
topic_csv.to_csv("../../data/evaluation_outputs/topic_comparison_v2.csv", index=False)

print(topic_csv[["new_topic_num", "new_topic_name", "old_topic_num", "old_topic_name", "renamed", "cosine_similarity", "match_quality"]].to_string(index=False))
print(f"\nRenamed: {sum(1 for r in rows if r['renamed'] == 'Yes')}/30")
print(f"Saved to data/evaluation_outputs/topic_comparison_v2.csv")
# Out:
#  new_topic_num                new_topic_name  old_topic_num                   old_topic_name renamed  cosine_similarity match_quality
#              0      child_and_family_support              0         child_and_family_support      No             0.9887        strong
#              1 academy_finance_and_oversight              1    academy_finance_and_oversight      No             1.0000        strong
#              2                mat_governance              2                   mat_governance      No             0.9990        strong
#              3                   teacher_pay              3                      teacher_pay      No             0.9999        strong
#              4            ofsted_inspections              4               ofsted_inspections      No             0.9993        strong
#              5                  exam_results              5              academic_attainment     Yes             0.9787        strong
#              6                 pupil_absence              6                    pupil_absence      No             0.9988        strong
#              7              dfe_intervention              7                 dfe_intervention      No             0.9995        strong
#              8      local_authority_deficits              8                   send_provision     Yes             0.7836      moderate
#              9               teacher_strikes              9                  teacher_strikes      No             0.9999        strong
#             10               apprenticeships             10                  apprenticeships      No             0.7696      moderate
#             11               exam_regulation             11                  exam_regulation      No             0.9324        strong
#             12                   raac_crisis             12                      raac_crisis      No             0.9989        strong
#             13          disadvantaged_groups             28                    school_places     Yes             0.9200        strong
#             14             free_school_meals             14                   school_funding     Yes             0.9976        strong
#             15            education_politics             15               education_politics      No             0.9992        strong
#             16            education_research             16               education_research      No             0.9916        strong
#             17       leadership_appointments             17          leadership_appointments      No             0.9956        strong
#             18                 ai_and_edtech             18                    ai_and_edtech      No             0.9807        strong
#             19                 mental_health             27                free_school_meals     Yes             0.9928        strong
#             20                    curriculum             24                curriculum_policy     Yes             0.9731        strong
#             21                  safeguarding             21                     safeguarding      No             0.9731        strong
#             22           teacher_recruitment             22              teacher_recruitment      No             0.9972        strong
#             23                school_funding             26 disadvantage_and_attainment_gaps     Yes             0.9980        strong
#             24        exclusions_suspensions             29                       exclusions     Yes             0.9994        strong
#             25                  report_cards             23            accountability_reform     Yes             0.9973        strong
#             26                send_inclusion              8                   send_provision     Yes             0.7131      moderate
#             27            primary_assessment             13      examinations_and_assessment     Yes             0.9648        strong
#             28                 school_places             28                    school_places      No             0.4626          weak
#             29               breakfast_clubs             25                  attendance_hubs     Yes             0.9962        strong
#
# Renamed: 12/30
# Saved to data/evaluation_outputs/topic_comparison_v2.csv

# %% [markdown]
# #### Cosine similarity measures keyword overlap, not meaning — four failure modes (same label/different content, different label/same content, appears changed/actually stable, appears stable/actually changed) cannot be resolved by the metric alone, making the human interpretation of topic comparisons a specification choice that should be logged and surfaced alongside the score.

# %% [markdown]
# ## 17. Retraining summary

# %%
print("=" * 60)
print("RETRAINING SUMMARY")
print("=" * 60)
print(f"Corpus:              3,943 articles (England, Jan 2023 - Dec 2025)")
print(f"Previous corpus:     3,972 articles (diff: 29 HE articles removed)")
print(f"k:                   30 (confirmed by coherence sweep)")
print(f"Reconstruction err:  {nmf_out.reconstruction_error:.4f} (prev: 53.3371)")
print(f"Coherence (c_v):     0.6902 (prev: 0.6940)")
print(f"Topic stability:     {avg_stability:.4f} (prev: 0.94)")
print(f"Topics shifted:      ~20 shuffled indices, ~8 recomposed, ~2 new splits")
print(f"LLM naming match:    1/30 exact match (topic 17: leadership_appointments)")
print("=" * 60)
# Out:
# ============================================================
# RETRAINING SUMMARY
# ============================================================
# Corpus:              3,943 articles (England, Jan 2023 - Dec 2025)
# Previous corpus:     3,972 articles (diff: 29 HE articles removed)
# k:                   30 (confirmed by coherence sweep)
# Reconstruction err:  53.1649 (prev: 53.3371)
# Coherence (c_v):     0.6902 (prev: 0.6940)
# Topic stability:     0.9375 (prev: 0.94)
# Topics shifted:      ~20 shuffled indices, ~8 recomposed, ~2 new splits
# LLM naming match:    1/30 exact match (topic 17: leadership_appointments)
# ============================================================

# %% [markdown]
# ## 18. Save retrained model artifacts

# %%
import joblib
import json
from datetime import datetime

run_id = datetime.now().strftime("%Y-%m-%d_%H%M%S")
run_dir = Path(f"../../experiments/outputs/runs/{run_id}")
run_dir.mkdir(parents=True, exist_ok=True)

# Save model + vectorizer
joblib.dump(nmf_out.nmf_model, run_dir / "nmf_model.joblib")
joblib.dump(vec_out.vectorizer, run_dir / "vectorizer.joblib")

# Save topic names
with open(run_dir / "topic_names.json", "w") as f:
    json.dump(NEW_TOPIC_NAMES, f, indent=2)

# Save run metadata
metadata = {
    "run_id": run_id,
    "n_articles": len(df),
    "n_topics": 30,
    "init": "nndsvd",
    "random_state": 42,
    "max_iter": 1000,
    "reconstruction_error": float(nmf_out.reconstruction_error),
    "tfidf_min_df": 3,
    "tfidf_max_df": 0.85,
    "tfidf_max_features": 3000,
    "tfidf_ngram_range": [1, 2],
    "vocabulary_size": len(vec_out.feature_names),
    "coherence_cv_k30": 0.6902,
    "topic_stability": float(avg_stability),
    "corpus": "eng_training_3943_supabase",
    "note": "Retrained after removing 29 HE articles. Topics shuffled indices vs previous run."
}
with open(run_dir / "run_metadata.json", "w") as f:
    json.dump(metadata, f, indent=2)

print(f"Saved to {run_dir}")
print(f"Contents: {[f.name for f in run_dir.iterdir()]}")
# Out:
# Saved to ../../experiments/outputs/runs/2026-03-19_160734
# Contents: ['vectorizer.joblib', 'nmf_model.joblib', 'run_metadata.json', 'topic_names.json']

# %% [markdown]
# ## Final Summary: Retraining, Specification Choices, and Contestability
#
# This notebook retrained an NMF topic model on an updated England corpus (3,943 articles), replacing a previous version trained on a near-identical dataset. The retraining process included full pipeline execution (cleaning, spaCy processing, TF-IDF vectorisation, and NMF training), followed by validation through coherence analysis, topic stability testing, and comparison with the previous model. Results show a high level of stability, with 26 out of 30 topics remaining strong matches (cosine similarity >0.80), indicating that the underlying thematic structure is largely unchanged despite minor corpus differences. Most topic changes reflect index reordering rather than substantive shifts in meaning, with 9 out of 11 renamed topics corresponding to stable content that had moved position or been previously mislabelled. The only meaningful structural change is the division of the original SEND topic into two distinct themes — local authority funding deficits and SEND inclusion — demonstrating improved granularity in the updated model. One topic (school_places) showed weaker alignment, reflecting recomposed content, but remained broadly interpretable.
#
# A key finding is that **topic labelling is not a model output but a specification choice**. While the model produces topic-word distributions, the assignment of meaningful names requires human interpretation of keywords. This process is sensitive to how many keywords are reviewed (e.g. top 20 vs 30 vs 50), who performs the interpretation, and how ambiguity is resolved. In this notebook, topic names were finalised through a combined LLM-assisted and manual review process: the LLM identified potential misalignments, while human judgement determined the final labels. This resulted in 11 renamings, improving clarity without altering the underlying model structure. Crucially, identical models could yield different labelled outputs depending on the reviewer, meaning topic naming must be treated as a documented and auditable decision.
#
# The use of cosine similarity to compare topics across models further illustrates the limits of automated evaluation. Cosine similarity measures keyword overlap rather than semantic meaning, leading to four potential failure modes: (1) different content with the same label, (2) same content with different labels, (3) apparent change where none exists, and (4) apparent stability masking recomposition. The SEND example demonstrates how a single topic can split into multiple themes, while the school_places topic shows how content can shift without triggering renaming. These cases highlight that **quantitative metrics alone cannot determine topic equivalence** — interpretation is required, particularly in the ambiguous mid-range of similarity scores. As such, similarity scores must always be reported alongside human reasoning, and thresholds should not be applied mechanically.
#
# These findings have broader implications for the use of topic modelling in policy analysis. The structure of topics depends on a series of specification choices, including the number of topics (*k*), preprocessing decisions, corpus composition, keyword depth, and labelling strategy. For example, varying *k* changes which policy areas are visible (e.g. SEND and council finance merge at k=25 but separate at k=30), while source concentration analysis shows that some topics are driven by specific publishers rather than the full policy landscape. This means that topic models do not passively reflect reality but actively shape how it is represented.
#
# From a governance perspective, this introduces important requirements for **transparency, contestability, and responsible use of AI**. Systems that use topic modelling to analyse policy discourse must make specification choices visible, document how topics are interpreted and labelled, and disclose uncertainty in cases where comparability is ambiguous. Metrics such as cosine similarity should be treated as inputs to interpretation rather than definitive indicators, and human judgement should be explicitly logged as part of the analytical process. Where findings are sensitive to modelling choices (e.g. *k* or corpus composition), this sensitivity should be disclosed rather than hidden.
#
# Overall, this retraining confirms that the model is stable and suitable for downstream analysis, while also demonstrating that **interpretation — not just computation — is central to topic modelling**. By combining quantitative validation with transparent qualitative judgement, the approach taken here supports more robust, interpretable, and contestable use of AI in policy research.
